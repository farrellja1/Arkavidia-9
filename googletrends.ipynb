# %%
import pandas as pd
from pytrends.request import TrendReq
import time
import logging

# %%
import pandas as pd
from pytrends.request import TrendReq
import logging
import time

def get_trend(keywords):
    logging.basicConfig(filename='scraping_errors.log', level=logging.ERROR)
    pytrends = TrendReq(hl='en-ID', tz=360)
    provinces = {
        "Aceh": "ID-AC",
        "Bali": "ID-BA",
        "Kepulauan Bangka Belitung": "ID-BB",
        "Banten": "ID-BT",
        "Bengkulu": "ID-BE",
        "Jawa Tengah": "ID-JT",
        "Kalimantan Tengah": "ID-KT",
        "Sulawesi Tengah": "ID-ST",
        "Jawa Timur": "ID-JI",
        "Kalimantan Timur": "ID-KI",
        "Nusa Tenggara Timur": "ID-NT",
        "Gorontalo": "ID-GO",
        "Jambi": "ID-JA",
        "Lampung": "ID-LA",
        "Maluku": "ID-MA",
        "Kalimantan Utara": "ID-KU",
        "Maluku Utara": "ID-MU",
        "Sulawesi Utara": "ID-SA",
        "Sumatera Utara": "ID-SU",
        "Papua": "ID-PA",
        "Riau": "ID-RI",
        "Kepulauan Riau": "ID-KR",
        "Sulawesi Tenggara": "ID-SG",
        "Kalimantan Selatan": "ID-KS",
        "Sulawesi Selatan": "ID-SN",
        "Sumatera Selatan": "ID-SS",
        "DKI Jakarta": "ID-JK",
        "DI Yogyakarta": "ID-YO",
        "Jawa Barat": "ID-JB",
        "Kalimantan Barat": "ID-KB",
        "Nusa Tenggara Barat": "ID-NB",
        "Papua Barat": "ID-PB",
        "Sulawesi Barat": "ID-SR",
        "Sumatera Barat": "ID-SB"
    }

    results_df = pd.DataFrame()

    for province, geo_code in provinces.items():
        attempt = 0
        while attempt < 5:  # Retry up to 5 times
            try:
                pytrends.build_payload(kw_list=keywords, timeframe='2024-10-01 2024-12-31', geo=geo_code)
                interest_over_time_df = pytrends.interest_over_time()
                
                if interest_over_time_df.empty:
                    raise ValueError("No data returned for this province.")
                
                interest_values = interest_over_time_df[keywords[0]].rename(province)
                if results_df.empty:
                    results_df = interest_values.to_frame()
                else:
                    results_df = results_df.join(interest_values)

                print(f"Interest over time for {province}:")
                print(interest_values.head())
                break  # Exit the retry loop if successful

            except Exception as e:
                logging.error(f"Error for {province}: {e}")
                attempt += 1
                time.sleep(5)
                if attempt == 5:
                    print(f"Failed to retrieve data for {province} after multiple attempts.")
                    if results_df.empty:
                        results_df = pd.DataFrame(index=pd.date_range(start='2024-10-01', end='2024-12-31'))
                    results_df[province] = 0
                    break

    results_df.reset_index(inplace=True)
    results_df.rename(columns={'index': 'Date'}, inplace=True)
    results_df.to_csv(f'{keywords[0]}.csv', index=False)

    return results_df

# %%
keywords = ['bawang merah', 'bawang putih', 'beras', 'cabai merah'
            , 'cabai rawit', 'daging ayam', 'daging sapi', 'gula', 'minyak goreng', 'telur ayam', 'tepung terigu']
for keyword in keywords:
    get_trend([keyword])
# Out:
# Interest over time for Aceh:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03     0
# 2024-10-04     0
# 2024-10-05    73
# Name: Aceh, dtype: int32
# Interest over time for Bali:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Bali, dtype: int32
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Interest over time for Banten:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Banten, dtype: int32
# Interest over time for Bengkulu:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Bengkulu, dtype: int32
# Interest over time for Jawa Tengah:
# date
# 2024-10-01    59
# 2024-10-02    58
# 2024-10-03    73
# 2024-10-04    40
# 2024-10-05    61
# Name: Jawa Tengah, dtype: int32
# Interest over time for Kalimantan Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Tengah, dtype: int32
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Interest over time for Kalimantan Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Timur, dtype: int32
# Interest over time for Nusa Tenggara Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Timur, dtype: int32
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Interest over time for Lampung:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Lampung, dtype: int32
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Interest over time for Sumatra Utara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sumatra Utara, dtype: int32
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Interest over time for Sulawesi Selatan:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Selatan, dtype: int32
# Interest over time for Sumatra Selatan:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sumatra Selatan, dtype: int32
# Interest over time for DKI Jakarta:
# date
# 2024-10-01    46
# 2024-10-02    80
# 2024-10-03    43
# 2024-10-04     0
# 2024-10-05     0
# Name: DKI Jakarta, dtype: int32
# Interest over time for DI Yogyakarta:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03    74
# 2024-10-04    94
# 2024-10-05     0
# Name: DI Yogyakarta, dtype: int32
# Interest over time for Jawa Barat:
# date
# 2024-10-01    63
# 2024-10-02    58
# 2024-10-03    82
# 2024-10-04    55
# 2024-10-05    84
# Name: Jawa Barat, dtype: int32
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Interest over time for Nusa Tenggara Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Barat, dtype: int32
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Interest over time for Banten:
# date
# 2024-10-01    72
# 2024-10-02    70
# 2024-10-03    50
# 2024-10-04    57
# 2024-10-05     0
# Name: Banten, dtype: int32
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Interest over time for Kalimantan Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Tengah, dtype: int32
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Interest over time for Kalimantan Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Timur, dtype: int32
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Interest over time for Maluku:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Maluku, dtype: int32
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Interest over time for Sulawesi Utara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Utara, dtype: int32
# Interest over time for Sumatra Utara:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03    62
# 2024-10-04     0
# 2024-10-05     0
# Name: Sumatra Utara, dtype: int32
# Failed to retrieve data for Papua after multiple attempts.
# Interest over time for Riau:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Riau, dtype: int32
# Interest over time for Riau Islands:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Riau Islands, dtype: int32
# Interest over time for Sulawesi Tenggara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Tenggara, dtype: int32
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Interest over time for Sulawesi Selatan:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Selatan, dtype: int32
# Interest over time for Sumatra Selatan:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03     0
# 2024-10-04    64
# 2024-10-05     0
# Name: Sumatra Selatan, dtype: int32
# Interest over time for DKI Jakarta:
# date
# 2024-10-01    53
# 2024-10-02    60
# 2024-10-03    70
# 2024-10-04    46
# 2024-10-05    55
# Name: DKI Jakarta, dtype: int32
# Interest over time for DI Yogyakarta:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: DI Yogyakarta, dtype: int32
# Interest over time for Jawa Barat:
# date
# 2024-10-01    62
# 2024-10-02    66
# 2024-10-03    67
# 2024-10-04    55
# 2024-10-05    35
# Name: Jawa Barat, dtype: int32
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Interest over time for Papua Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Papua Barat, dtype: int32
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Interest over time for Aceh:
# date
# 2024-10-01    52
# 2024-10-02    66
# 2024-10-03    50
# 2024-10-04     0
# 2024-10-05     0
# Name: Aceh, dtype: int32
# Interest over time for Bali:
# date
# 2024-10-01     0
# 2024-10-02    47
# 2024-10-03     0
# 2024-10-04    45
# 2024-10-05     0
# Name: Bali, dtype: int32
# Interest over time for Bangka Belitung Islands:
# date
# 2024-10-01      0
# 2024-10-02      0
# 2024-10-03      0
# 2024-10-04      0
# 2024-10-05    100
# Name: Bangka Belitung Islands, dtype: int32
# Interest over time for Banten:
# date
# 2024-10-01    80
# 2024-10-02    65
# 2024-10-03    61
# 2024-10-04    55
# 2024-10-05    57
# Name: Banten, dtype: int32
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Interest over time for Kalimantan Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Tengah, dtype: int32
# Interest over time for Sulawesi Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Tengah, dtype: int32
# Interest over time for Jawa Timur:
# date
# 2024-10-01    77
# 2024-10-02    77
# 2024-10-03    85
# 2024-10-04    58
# 2024-10-05    76
# Name: Jawa Timur, dtype: int32
# Interest over time for Kalimantan Timur:
# date
# 2024-10-01    58
# 2024-10-02    61
# 2024-10-03    66
# 2024-10-04    48
# 2024-10-05     0
# Name: Kalimantan Timur, dtype: int32
# Interest over time for Nusa Tenggara Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Timur, dtype: int32
# Failed to retrieve data for Gorontalo after multiple attempts.
# Interest over time for Jambi:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Jambi, dtype: int32
# Failed to retrieve data for Lampung after multiple attempts.
# Interest over time for Maluku:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Maluku, dtype: int32
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Interest over time for Maluku Utara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Maluku Utara, dtype: int32
# Interest over time for Sulawesi Utara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Utara, dtype: int32
# Interest over time for Sumatra Utara:
# date
# 2024-10-01    49
# 2024-10-02    71
# 2024-10-03    92
# 2024-10-04    52
# 2024-10-05    71
# Name: Sumatra Utara, dtype: int32
# Interest over time for Papua:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Papua, dtype: int32
# Interest over time for Riau:
# date
# 2024-10-01    36
# 2024-10-02    52
# 2024-10-03    42
# 2024-10-04    53
# 2024-10-05     0
# Name: Riau, dtype: int32
# Interest over time for Riau Islands:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Riau Islands, dtype: int32
# Interest over time for Sulawesi Tenggara:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03    45
# 2024-10-04     0
# 2024-10-05     0
# Name: Sulawesi Tenggara, dtype: int32
# Interest over time for Kalimantan Selatan:
# date
# 2024-10-01    56
# 2024-10-02    66
# 2024-10-03    60
# 2024-10-04     0
# 2024-10-05     0
# Name: Kalimantan Selatan, dtype: int32
# Interest over time for Sulawesi Selatan:
# date
# 2024-10-01    69
# 2024-10-02    57
# 2024-10-03    84
# 2024-10-04    43
# 2024-10-05    66
# Name: Sulawesi Selatan, dtype: int32
# Interest over time for Sumatra Selatan:
# date
# 2024-10-01    74
# 2024-10-02    53
# 2024-10-03    50
# 2024-10-04    53
# 2024-10-05    37
# Name: Sumatra Selatan, dtype: int32
# Interest over time for DKI Jakarta:
# date
# 2024-10-01    84
# 2024-10-02    76
# 2024-10-03    67
# 2024-10-04    78
# 2024-10-05    62
# Name: DKI Jakarta, dtype: int32
# Interest over time for DI Yogyakarta:
# date
# 2024-10-01    71
# 2024-10-02    59
# 2024-10-03    66
# 2024-10-04    68
# 2024-10-05    44
# Name: DI Yogyakarta, dtype: int32
# Interest over time for Jawa Barat:
# date
# 2024-10-01    59
# 2024-10-02    70
# 2024-10-03    69
# 2024-10-04    55
# 2024-10-05    58
# Name: Jawa Barat, dtype: int32
# Interest over time for Kalimantan Barat:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03    50
# 2024-10-04     0
# 2024-10-05    62
# Name: Kalimantan Barat, dtype: int32
# Interest over time for Nusa Tenggara Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Barat, dtype: int32
# Failed to retrieve data for Papua Barat after multiple attempts.
# Interest over time for Sulawesi Barat:
# date
# 2024-10-01     0
# 2024-10-02    56
# 2024-10-03     0
# 2024-10-04     0
# 2024-10-05     0
# Name: Sulawesi Barat, dtype: int32
# Interest over time for Sumatra Barat:
# date
# 2024-10-01     0
# 2024-10-02    54
# 2024-10-03    62
# 2024-10-04     0
# 2024-10-05     0
# Name: Sumatra Barat, dtype: int32
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Interest over time for Jawa Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Jawa Tengah, dtype: int32
# Interest over time for Kalimantan Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Tengah, dtype: int32
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Interest over time for Jambi:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Jambi, dtype: int32
# Interest over time for Lampung:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Lampung, dtype: int32
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Interest over time for Riau:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Riau, dtype: int32
# Interest over time for Riau Islands:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Riau Islands, dtype: int32
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Interest over time for Kalimantan Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Barat, dtype: int32
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Interest over time for Sulawesi Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Barat, dtype: int32
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Interest over time for Kalimantan Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Tengah, dtype: int32
# Interest over time for Sulawesi Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Tengah, dtype: int32
# Interest over time for Jawa Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Jawa Timur, dtype: int32
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Interest over time for Kalimantan Utara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Utara, dtype: int32
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Interest over time for Sulawesi Tenggara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Tenggara, dtype: int32
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Interest over time for Sulawesi Selatan:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Selatan, dtype: int32
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Interest over time for Jawa Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Jawa Barat, dtype: int32
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Interest over time for Nusa Tenggara Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Barat, dtype: int32
# Interest over time for Papua Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Papua Barat, dtype: int32
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Interest over time for Bali:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Bali, dtype: int32
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Interest over time for Banten:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Banten, dtype: int32
# Interest over time for Bengkulu:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Bengkulu, dtype: int32
# Interest over time for Jawa Tengah:
# date
# 2024-10-01    71
# 2024-10-02    42
# 2024-10-03     0
# 2024-10-04     0
# 2024-10-05     0
# Name: Jawa Tengah, dtype: int32
# Failed to retrieve data for Kalimantan Tengah after multiple attempts.
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Interest over time for Jawa Timur:
# date
# 2024-10-01    87
# 2024-10-02    61
# 2024-10-03    58
# 2024-10-04    51
# 2024-10-05     0
# Name: Jawa Timur, dtype: int32
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Interest over time for Nusa Tenggara Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Timur, dtype: int32
# Interest over time for Gorontalo:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Gorontalo, dtype: int32
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Failed to retrieve data for Kalimantan Tengah after multiple attempts.
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Failed to retrieve data for Kalimantan Tengah after multiple attempts.
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Failed to retrieve data for Kalimantan Tengah after multiple attempts.
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Failed to retrieve data for Kalimantan Tengah after multiple attempts.
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.
# Failed to retrieve data for Aceh after multiple attempts.
# Failed to retrieve data for Bali after multiple attempts.
# Failed to retrieve data for Bangka Belitung Islands after multiple attempts.
# Failed to retrieve data for Banten after multiple attempts.
# Failed to retrieve data for Bengkulu after multiple attempts.
# Failed to retrieve data for Jawa Tengah after multiple attempts.
# Failed to retrieve data for Kalimantan Tengah after multiple attempts.
# Failed to retrieve data for Sulawesi Tengah after multiple attempts.
# Failed to retrieve data for Jawa Timur after multiple attempts.
# Failed to retrieve data for Kalimantan Timur after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Timur after multiple attempts.
# Failed to retrieve data for Gorontalo after multiple attempts.
# Failed to retrieve data for Jambi after multiple attempts.
# Failed to retrieve data for Lampung after multiple attempts.
# Failed to retrieve data for Maluku after multiple attempts.
# Failed to retrieve data for Kalimantan Utara after multiple attempts.
# Failed to retrieve data for Maluku Utara after multiple attempts.
# Failed to retrieve data for Sulawesi Utara after multiple attempts.
# Failed to retrieve data for Sumatra Utara after multiple attempts.
# Failed to retrieve data for Papua after multiple attempts.
# Failed to retrieve data for Riau after multiple attempts.
# Failed to retrieve data for Riau Islands after multiple attempts.
# Failed to retrieve data for Sulawesi Tenggara after multiple attempts.
# Failed to retrieve data for Kalimantan Selatan after multiple attempts.
# Failed to retrieve data for Sulawesi Selatan after multiple attempts.
# Failed to retrieve data for Sumatra Selatan after multiple attempts.
# Failed to retrieve data for DKI Jakarta after multiple attempts.
# Failed to retrieve data for DI Yogyakarta after multiple attempts.
# Failed to retrieve data for Jawa Barat after multiple attempts.
# Failed to retrieve data for Kalimantan Barat after multiple attempts.
# Failed to retrieve data for Nusa Tenggara Barat after multiple attempts.
# Failed to retrieve data for Papua Barat after multiple attempts.
# Failed to retrieve data for Sulawesi Barat after multiple attempts.
# Failed to retrieve data for Sumatra Barat after multiple attempts.

# %%
def get_trend2(keywords):
    pytrends = TrendReq(hl='en-ID', tz=360)
    provinces = {
        "Aceh": "ID-AC",
        "Bali": "ID-BA",
        "Bangka Belitung Islands": "ID-BB",
        "Banten": "ID-BT",
        "Bengkulu": "ID-BE",
        "Jawa Tengah": "ID-JT",
        "Kalimantan Tengah": "ID-KT",
        "Sulawesi Tengah": "ID-ST",
        "Jawa Timur": "ID-JI",
        "Kalimantan Timur": "ID-KI",
        "Nusa Tenggara Timur": "ID-NT",
        "Gorontalo": "ID-GO",
        "Jambi": "ID-JA",
        "Lampung": "ID-LA",
        "Maluku": "ID-MA",
        "Kalimantan Utara": "ID-KU",
        "Maluku Utara": "ID-MU",
        "Sulawesi Utara": "ID-SA",
        "Sumatra Utara": "ID-SU",
        "Papua": "ID-PA",
        "Riau": "ID-RI",
        "Riau Islands": "ID-KR",
        "Sulawesi Tenggara": "ID-SG",
        "Kalimantan Selatan": "ID-KS",
        "Sulawesi Selatan": "ID-SN",
        "Sumatra Selatan": "ID-SS",
        "DKI Jakarta": "ID-JK",
        "DI Yogyakarta": "ID-YO",
        "Jawa Barat": "ID-JB",
        "Kalimantan Barat": "ID-KB",
        "Nusa Tenggara Barat": "ID-NB",
        "Papua Barat": "ID-PB",
        "Sulawesi Barat": "ID-SR",
        "Sumatra Barat": "ID-SB"
    }

    results_df = pd.DataFrame()

    for province, geo_code in provinces.items():
        try:
            pytrends.build_payload(kw_list=keywords, timeframe='2024-10-01 2024-12-31', geo=geo_code)
            interest_over_time_df = pytrends.interest_over_time()
            interest_values = interest_over_time_df[keywords[0]].rename(province)
            interest_values.name = province
            if results_df.empty:
                results_df = interest_values.to_frame()
            else:
                results_df = results_df.join(interest_values)
            print(f"Interest over time for {province}:")
            print(interest_values.head())
        
        except Exception as e:
            print(f"An error occurred for {province}: {e}")
        # time.sleep(5)
        
    results_df.reset_index(inplace=True)
    results_df.rename(columns={'index': 'Date'}, inplace=True)

    results_df.to_csv('google_trends_results.csv', index=False)

    return results_df

# %%
get_trend2(keywords)
# Out:
# Interest over time for Aceh:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03     0
# 2024-10-04     0
# 2024-10-05    73
# Name: Aceh, dtype: int32
# Interest over time for Bali:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Bali, dtype: int32
# An error occurred for Bangka Belitung Islands: 'bawang merah'
# Interest over time for Banten:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03     0
# 2024-10-04     0
# 2024-10-05    79
# Name: Banten, dtype: int32
# Interest over time for Bengkulu:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Bengkulu, dtype: int32
# Interest over time for Jawa Tengah:
# date
# 2024-10-01    59
# 2024-10-02    58
# 2024-10-03    73
# 2024-10-04    40
# 2024-10-05    61
# Name: Jawa Tengah, dtype: int32
# Interest over time for Kalimantan Tengah:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Kalimantan Tengah, dtype: int32
# An error occurred for Sulawesi Tengah: 'bawang merah'
# Interest over time for Jawa Timur:
# date
# 2024-10-01    51
# 2024-10-02    74
# 2024-10-03    63
# 2024-10-04    51
# 2024-10-05    49
# Name: Jawa Timur, dtype: int32
# An error occurred for Kalimantan Timur: 'bawang merah'
# Interest over time for Nusa Tenggara Timur:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Timur, dtype: int32
# Interest over time for Gorontalo:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Gorontalo, dtype: int32
# An error occurred for Jambi: 'bawang merah'
# Interest over time for Lampung:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Lampung, dtype: int32
# An error occurred for Maluku: 'bawang merah'
# An error occurred for Kalimantan Utara: 'bawang merah'
# An error occurred for Maluku Utara: 'bawang merah'
# An error occurred for Sulawesi Utara: 'bawang merah'
# Interest over time for Sumatra Utara:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sumatra Utara, dtype: int32
# An error occurred for Papua: 'bawang merah'
# An error occurred for Riau: 'bawang merah'
# Interest over time for Riau Islands:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Riau Islands, dtype: int32
# An error occurred for Sulawesi Tenggara: 'bawang merah'
# An error occurred for Kalimantan Selatan: 'bawang merah'
# Interest over time for Sulawesi Selatan:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Selatan, dtype: int32
# Interest over time for Sumatra Selatan:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sumatra Selatan, dtype: int32
# Interest over time for DKI Jakarta:
# date
# 2024-10-01    42
# 2024-10-02    72
# 2024-10-03    39
# 2024-10-04     0
# 2024-10-05     0
# Name: DKI Jakarta, dtype: int32
# Interest over time for DI Yogyakarta:
# date
# 2024-10-01     0
# 2024-10-02     0
# 2024-10-03     0
# 2024-10-04    94
# 2024-10-05     0
# Name: DI Yogyakarta, dtype: int32
# Interest over time for Jawa Barat:
# date
# 2024-10-01    63
# 2024-10-02    58
# 2024-10-03    77
# 2024-10-04    55
# 2024-10-05    84
# Name: Jawa Barat, dtype: int32
# An error occurred for Kalimantan Barat: 'bawang merah'
# Interest over time for Nusa Tenggara Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Nusa Tenggara Barat, dtype: int32
# An error occurred for Papua Barat: 'bawang merah'
# Interest over time for Sulawesi Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sulawesi Barat, dtype: int32
# Interest over time for Sumatra Barat:
# date
# 2024-10-01    0
# 2024-10-02    0
# 2024-10-03    0
# 2024-10-04    0
# 2024-10-05    0
# Name: Sumatra Barat, dtype: int32
#          date  Aceh  Bali  Banten  Bengkulu  Jawa Tengah  Kalimantan Tengah  \
# 0  2024-10-01     0     0       0         0           59                  0
# 1  2024-10-02     0     0       0         0           58                  0
# 2  2024-10-03     0     0       0         0           73                  0
# 3  2024-10-04     0     0       0         0           40                  0
# 4  2024-10-05    73     0      79         0           61                  0
# ..        ...   ...   ...     ...       ...          ...                ...
# 87 2024-12-27     0     0       0         0           37                  0
# 88 2024-12-28     0     0       0         0           66                  0
# 89 2024-12-29     0     0       0         0           54                  0
# 90 2024-12-30     0     0       0         0          100                  0
# 91 2024-12-31     0     0       0         0           46                  0
#
#     Jawa Timur  Nusa Tenggara Timur  Gorontalo  ...  Sumatra Utara  \
# 0           51                    0          0  ...              0
# 1           74                    0          0  ...              0
# 2           63                    0          0  ...              0
# 3           51                    0          0  ...              0
# 4           49                    0          0  ...              0
# ..         ...                  ...        ...  ...            ...
# 87          39                    0          0  ...              0
# 88          49                    0          0  ...              0
# 89          31                    0          0  ...              0
# 90          45                    0          0  ...              0
# 91          71                    0          0  ...              0
#
#     Riau Islands  Sulawesi Selatan  Sumatra Selatan  DKI Jakarta  \
# 0              0                 0                0           42
# 1              0                 0                0           72
# 2              0                 0                0           39
# 3              0                 0                0            0
# 4              0                 0                0            0
# ..           ...               ...              ...          ...
# 87             0                 0                0            0
# 88             0                 0                0            0
# 89             0                 0                0            0
# 90             0                 0              100            0
# 91             0                 0                0            0
#
#     DI Yogyakarta  Jawa Barat  Nusa Tenggara Barat  Sulawesi Barat  \
# 0               0          63                    0               0
# 1               0          58                    0               0
# 2               0          77                    0               0
# 3              94          55                    0               0
# 4               0          84                    0               0
# ..            ...         ...                  ...             ...
# 87              0          53                    0               0
# 88              0          50                    0               0
# 89              0          34                    0               0
# 90              0          58                    0               0
# 91              0          35                    0               0
#
#     Sumatra Barat
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 87              0
# 88              0
# 89              0
# 90              0
# 91              0
#
# [92 rows x 21 columns]
